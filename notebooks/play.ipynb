# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# /home/rainorangelemon/Documents/tiny-diffusion
# /home/rainorangelemon/micromamba/envs/robodiff/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# create a benchmark of distributions
import numpy as np
from datasets import composition_product_1_dataset, composition_product_2_dataset

# %%
points = composition_product_1_dataset(1000).tensors[0].numpy()

# %%
# draw the points
import matplotlib.pyplot as plt
plt.scatter(points[:, 0], points[:, 1])
plt.show()
