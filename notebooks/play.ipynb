# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# /home/rainorangelemon/Documents/tiny-diffusion
# /home/rainorangelemon/micromamba/envs/robodiff/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# create a benchmark of distributions
import numpy as np
from datasets import generate_data_points

# %%
points_1 = generate_data_points(n=8000, dataset='negation_a3')
points_2 = generate_data_points(n=8000, dataset='negation_a3')

# %%
# plot the data
import matplotlib.pyplot as plt
plt.scatter(points_1[:, 0], points_1[:, 1], s=1)
plt.show()
